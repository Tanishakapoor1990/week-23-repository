# %% [markdown]
# Expand the flask app from class to add functions to create, update, and delete records.
# Use the mongodb documentation https://docs.mongodb.com/manual/reference/ . Create
# can use insert_one method, update can use update_one, and delete can use
# delete_one.

# %% [markdown]
# ![first.PNG](attachment:first.PNG)

# %% [markdown]
# I inserted Ozark tv show with follwing details :
#
# - number of seasons -10
# - duration - 45 minutes
# - year - 2020

# %% [markdown]
# ![insert.PNG](attachment:insert.PNG)

# %% [markdown]
# I updated my above added record by changing  duration of Ozark Tv show to 1 hour from 45 minutes
# also changed year from 2020 to 2018

# %% [markdown]
# ![update.PNG](attachment:update.PNG)

# %% [markdown]
# Finally I deleted my Ozark record

# %% [markdown]
# ![delete.PNG](attachment:delete.PNG)
